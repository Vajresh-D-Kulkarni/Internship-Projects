# %% [markdown]
# # Major Project

# %% [markdown]
# ## Importing Necessory Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings             # here we use imported the warning library which is use to aviod the unwanted warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('heart.csv')

# %%
df.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             918 non-null    int64
#  1   Sex             918 non-null    object
#  2   ChestPainType   918 non-null    object
#  3   RestingBP       918 non-null    int64
#  4   Cholesterol     918 non-null    int64
#  5   FastingBS       918 non-null    int64
#  6   RestingECG      918 non-null    object
#  7   MaxHR           918 non-null    int64
#  8   ExerciseAngina  918 non-null    object
#  9   Oldpeak         918 non-null    float64
#  10  ST_Slope        918 non-null    object
#  11  HeartDisease    918 non-null    int64
# dtypes: float64(1), int64(6), object(5)
# memory usage: 86.2+ KB

# %%
df.isnull().sum()
# Out:
# Age               0
# Sex               0
# ChestPainType     0
# RestingBP         0
# Cholesterol       0
# FastingBS         0
# RestingECG        0
# MaxHR             0
# ExerciseAngina    0
# Oldpeak           0
# ST_Slope          0
# HeartDisease      0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Age', 'Sex', 'ChestPainType', 'RestingBP', 'Cholesterol', 'FastingBS',
#        'RestingECG', 'MaxHR', 'ExerciseAngina', 'Oldpeak', 'ST_Slope',
#        'HeartDisease'],
#       dtype='object')

# %% [markdown]
# ## Data Preprocessing

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()

# %%
df['Sex']=encoder.fit_transform(df['Sex'])

# %%
df.head(2)
# Out:
#    Age  Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0   40    1           ATA        140          289          0     Normal
# 1   49    0           NAP        160          180          0     Normal
#
#    MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0    172              N      0.0       Up             0
# 1    156              N      1.0     Flat             1

# %%
df['ChestPainType']=encoder.fit_transform(df['ChestPainType'])

# %%
df['RestingECG']=encoder.fit_transform(df['RestingECG'])

# %%
df['ExerciseAngina']=encoder.fit_transform(df['ExerciseAngina'])

# %%
df['ST_Slope']=encoder.fit_transform(df['ST_Slope'])

# %%
df.head(2)
# Out:
#    Age  Sex  ChestPainType  RestingBP  Cholesterol  FastingBS  RestingECG  \
# 0   40    1              1        140          289          0           1
# 1   49    0              2        160          180          0           1
#
#    MaxHR  ExerciseAngina  Oldpeak  ST_Slope  HeartDisease
# 0    172               0      0.0         2             0
# 1    156               0      1.0         1             1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             918 non-null    int64
#  1   Sex             918 non-null    int32
#  2   ChestPainType   918 non-null    int32
#  3   RestingBP       918 non-null    int64
#  4   Cholesterol     918 non-null    int64
#  5   FastingBS       918 non-null    int64
#  6   RestingECG      918 non-null    int32
#  7   MaxHR           918 non-null    int64
#  8   ExerciseAngina  918 non-null    int32
#  9   Oldpeak         918 non-null    float64
#  10  ST_Slope        918 non-null    int32
#  11  HeartDisease    918 non-null    int64
# dtypes: float64(1), int32(5), int64(6)
# memory usage: 68.3 KB

# %%
df.shape
# Out:
# (918, 12)

# %%
df.head()
# Out:
#    Age  Sex  ChestPainType  RestingBP  Cholesterol  FastingBS  RestingECG  \
# 0   40    1              1        140          289          0           1
# 1   49    0              2        160          180          0           1
# 2   37    1              1        130          283          0           2
# 3   48    0              0        138          214          0           1
# 4   54    1              2        150          195          0           1
#
#    MaxHR  ExerciseAngina  Oldpeak  ST_Slope  HeartDisease
# 0    172               0      0.0         2             0
# 1    156               0      1.0         1             1
# 2     98               0      0.0         2             0
# 3    108               1      1.5         1             1
# 4    122               0      0.0         2             0

# %%
X = df.drop(columns=['HeartDisease'],axis=1)
y = df[['HeartDisease']]

# %%
X.head()
# Out:
#    Age  Sex  ChestPainType  RestingBP  Cholesterol  FastingBS  RestingECG  \
# 0   40    1              1        140          289          0           1
# 1   49    0              2        160          180          0           1
# 2   37    1              1        130          283          0           2
# 3   48    0              0        138          214          0           1
# 4   54    1              2        150          195          0           1
#
#    MaxHR  ExerciseAngina  Oldpeak  ST_Slope
# 0    172               0      0.0         2
# 1    156               0      1.0         1
# 2     98               0      0.0         2
# 3    108               1      1.5         1
# 4    122               0      0.0         2

# %% [markdown]
# ## Data visualization

# %%
correlation_matrix = df.corr()    # This will give us the corrilation among all the columns

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# ### this is the heatmap which will give us the correlation among each cell among each cell

# %%
plt.figure(figsize=(8, 6))
sns.histplot(df['HeartDisease'], bins=30, kde=True)
plt.title('Heart Disease Distribution')
plt.xlabel('Heart Disease')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='ChestPainType', y='HeartDisease', data=df)
plt.title('Chest pain vs Heart Disease')
plt.xticks(rotation=0)
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(df['Cholesterol'], label='Heart Disease', color='blue')
plt.title('Cholesterol vs Heart Disease')
plt.xlabel('Cholesterol')
plt.ylabel('Heart Disease')
plt.legend()
plt.show()

# %%
selected_columns = ['ChestPainType', 'RestingBP', 'Cholesterol', 'RestingECG', 'MaxHR', 'ExerciseAngina', 'HeartDisease']

plt.figure(figsize=(12, 8))
sns.pairplot(df[selected_columns])
plt.suptitle('Pair Plot of Selected Columns', y=1.02)
plt.show()

# %% [markdown]
# ### This is the pair plot which is same as the heatmap.
# ### It is also gives us the correlation with each cells but in the graphical format.

# %% [markdown]
# ## Valuable Insides ##
# ### In our project ###
# 1. In our project we use the three algorithms namely logistic regression, Random forest, Decision Tree and Support Vector Classifier.
# 2. As our dataset the not continuous we use the Classification Algorithm.
# 3. Among the three algorithm the Support Vector Classifier gives us the best accuracy.

# %% [markdown]
# ## Insides ##
# 1. This is Visualization technique for this we use matplotlib, seaborn
# 2. The visualization is help us in understanding the dataset.
# 3. We can also determine which algorithm is used for our dataset.

# %% [markdown]
# ## Model Building

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=1/4,random_state=0)

# %%
X_train.shape,X_test.shape,y_train.shape,y_test.shape
# Out:
# ((688, 11), (230, 11), (688, 1), (230, 1))

# %%
from sklearn.preprocessing import StandardScaler
scale = StandardScaler()

# %%
X_train = scale.fit_transform(X_train)
X_test = scale.transform(X_test)

# %% [markdown]
# ## Model Training and Model Testing With Evaluation and Accuarcy

# %% [markdown]
# ### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
reg = LogisticRegression()

# %%
reg.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred = reg.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,accuracy_score,confusion_matrix
ac = accuracy_score(y_test,y_pred)
cm = confusion_matrix(y_test,y_pred)
print("Accuracy Score is ",ac*100)
print("Confusion Matrix is ")
cm
# Out:
# Accuracy Score is  83.04347826086956
# Confusion Matrix is
# array([[ 70,  22],
#        [ 17, 121]], dtype=int64)

# %% [markdown]
# ### Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier
tree = DecisionTreeClassifier()

# %%
tree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred = tree.predict(X_test)

# %%
ac = accuracy_score(y_test,y_pred)
cm = confusion_matrix(y_test,y_pred)
print("Accuracy Score is ",ac*100)
print("Confusion Matrix is ")
cm
# Out:
# Accuracy Score is  82.17391304347827
# Confusion Matrix is
# array([[ 72,  20],
#        [ 21, 117]], dtype=int64)

# %% [markdown]
# ### Support Vector Classifier

# %%
from sklearn.svm import SVC
svm = SVC()

# %%
svm.fit(X_train, y_train)
# Out:
# SVC()

# %%
y_pred = svm.predict(X_test)

# %%
ac = accuracy_score(y_test,y_pred)
cm = confusion_matrix(y_test,y_pred)
print("Accuracy Score is ",ac*100)
print("Confusion Matrix is ")
cm
# Out:
# Accuracy Score is  86.52173913043478
# Confusion Matrix is
# array([[ 72,  20],
#        [ 11, 127]], dtype=int64)

# %%
from sklearn.ensemble import RandomForestClassifier
forest = RandomForestClassifier()

# %%
forest.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred = forest.predict(X_test)

# %%
print("Mean Squared Error is ",mean_squared_error(y_test,y_pred))
# Out:
# Mean Squared Error is  0.14347826086956522

# %%
ac = accuracy_score(y_test,y_pred)
cm = confusion_matrix(y_test,y_pred)
print("Accuracy Score is ",ac*100)
print("Confusion Matrix is ")
cm
# Out:
# Accuracy Score is  85.65217391304348
# Confusion Matrix is
# array([[ 74,  18],
#        [ 15, 123]], dtype=int64)
